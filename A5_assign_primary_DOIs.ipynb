# %% [markdown]
# ### We will now bring together the lists of CrossRef-acquired DOIs and the manually-identified last few

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##  bring in the main list of all 2377 publications claimed in BRC phase2
#  file as exported from notebook A4   ('./A4out_CrossRef_FuzzyMatched_with_retry_Oct19.csv')

# %%
df_main = pd.read_csv('./Source_files/A4out_CrossRef_FuzzyMatched_with_retry_Oct19.csv', index_col=0)
df_main.shape
# Out:
# (2378, 21)

# %%
df_main.head(2)
# Out:
#      ID                          DOI  \
# 0  1125    10.1186/s12881-014-0095-4
# 1  1996  10.1183/13993003.00321-2016
#
#                                             complete  \
# 0  &amp; , fenwick al, goos jac, rankin j, lord h...
# 1  , pattinson kt, turner mr. a wider pathologica...
#
#                                       csv_post_title  \
# 0  apparently synonymous substitutions in fgfr2 a...
# 1  a wider pathological network underlying breath...
#
#                                     crossref_API_out  \
# 0  {'title': ['Apparently synonymous substitution...
# 1  {'title': ['A wider pathological network under...
#
#                                                title  \
# 0  ['Apparently synonymous substitutions in FGFR2...
# 1  ['A wider pathological network underlying brea...
#
#                        DOI_API  \
# 0    10.1186/s12881-014-0095-4
# 1  10.1183/13993003.00321-2016
#
#                                            title_API  title_match  DOI_match  \
# 0  Apparently synonymous substitutions in FGFR2af...        False       True
# 1  A wider pathological network underlying breath...         True       True
#
#    ... DOI_fuzzyRatio  Title_fuzzyRatio  Title_partialRatio  \
# 0  ...          100.0              99.0                99.0
# 1  ...          100.0             100.0               100.0
#
#    Complete_fuzzyRatio  Complete_partialRatio  TitleMatch01  good_list  \
# 0                 51.0                   99.0             0       True
# 1                 73.0                  100.0             1       True
#
#    good_list2  DOI_retry_API title_retry_API
# 0        True            NaN             NaN
# 1        True            NaN             NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Then bring in the shorter list of Curated (manually checked) DOIs

# %%
df_curated = pd.read_csv('./Source_files/A5in_curated_API_list(14Oct19).csv', index_col=0, usecols=[0,1,5])
df_curated.head()
# Out:
#              ID                     curated_DOI
# Column1
# 105.0    1467.0   10.3109/10428194.2015.1122783
# 33.0     1639.0   10.1080/23279095.2014.1003067
# 37.0     1313.0            10.1093/brain/awu328
# 38.0     1448.0  10.1523/jneurosci.3075-14.2015
# 39.0     1270.0       10.1007/s11892-014-0559-0

# %%
df_curated.count()
# Out:
# ID             176
# curated_DOI    165
# dtype: int64

# %% [markdown]
# ### Then add 'curated_DOI column to df_api (merge using the 'ID' column)

# %%
df_DOIs = df_main.merge(df_curated, on='ID',how='left')
df_DOIs.shape
# Out:
# (2378, 22)

# %%
df_DOIs.count()
# Out:
# ID                       2378
# DOI                      1442
# complete                 2378
# csv_post_title           2378
# crossref_API_out         2378
# title                    2378
# DOI_API                  2378
# title_API                2082
# title_match              2378
# DOI_match                2378
# CrossRefTitle_low        2082
# DOI_fuzzyRatio           1442
# Title_fuzzyRatio         2082
# Title_partialRatio       2082
# Complete_fuzzyRatio      2082
# Complete_partialRatio    2082
# TitleMatch01             2378
# good_list                2378
# good_list2               2378
# DOI_retry_API             562
# title_retry_API           562
# curated_DOI               165
# dtype: int64

# %% [markdown]
# ### Now define DOI to use from all references:
#     - If there was a good match on title or DOI orginially, use this DOI
#     - Where this was not the case, use exact matches from search of CrossRef using the 'complete'record
#     - if a 'curated_DOI' is available, use this preferentially
#     - remove any whitespace or full-stops from the DOIs

# %%
df_DOIs['FinalDOI']= np.nan

# %%
# be careful, the 'where' command is the reverse of this (replace when False)

df_DOIs['FinalDOI'].mask(df_DOIs.good_list==True, df_DOIs.DOI_API, inplace=True)

df_DOIs['FinalDOI'].mask(((df_DOIs.good_list==False)&(df_DOIs.good_list2==True)),
                         df_DOIs.DOI_retry_API, inplace=True)

df_DOIs['FinalDOI'].mask(df_DOIs.curated_DOI.notna(), df_DOIs.curated_DOI, inplace=True)

df_DOIs['FinalDOI'] = df_DOIs['FinalDOI'].str.strip(' .')

# %%
df_DOIs.count()
# Out:
# ID                       2378
# DOI                      1442
# complete                 2378
# csv_post_title           2378
# crossref_API_out         2378
# title                    2378
# DOI_API                  2378
# title_API                2082
# title_match              2378
# DOI_match                2378
# CrossRefTitle_low        2082
# DOI_fuzzyRatio           1442
# Title_fuzzyRatio         2082
# Title_partialRatio       2082
# Complete_fuzzyRatio      2082
# Complete_partialRatio    2082
# TitleMatch01             2378
# good_list                2378
# good_list2               2378
# DOI_retry_API             562
# title_retry_API           562
# curated_DOI               165
# FinalDOI                 2367
# dtype: int64

# %%
df_future_self = pd.read_csv('./Source_files/A5in_Rechecked_DOIs_after_author_numbers(Nov19).csv')
df_future_self
# Out:
#                                  DOI                  Recurated_DOI
# 0                10.1056/nejmx120009            10.1056/nejmx120009
# 1      10.1016/s0140-6736(12)60768-5  10.1016/s0140-6736(12)60768-5
# 2        10.1097/md.0b013e3182963750    10.1097/MD.0b013e31828a01f9
# 3               10.1056/nejmc1303486          10.1056/NEJMoa1110039
# 4                  10.1136/bmj.f4799              10.1136/bmj.f4303
# 5            10.1038/sj.bdj.2013.807   10.1371/journal.pmed.1001474
# 6                  10.1002/ana.24105              10.1002/ana.23838
# 7               10.1056/nejmc1315848          10.1056/NEJMoa1307557
# 8            10.1038/sj.bdj.2015.166  10.1016/S0140-6736(14)62007-9
# 9               10.1056/nejmc1505499          10.1056/NEJMoa1411627
# 10                 10.1111/jgh.13094     10.1016/j.jaci.2015.09.048
# 11           10.1161/jaha.115.001992        10.1161/JAHA.115.001926
# 12               10.1056/nejmx160012          10.1056/NEJMoa1507652
# 13              10.1056/nejmc1608082          10.1056/nejmoa1507750
# 14  10.1136/bmjopen-2015-009282corr1    10.1136/bmjopen-2015-009282

# %%
df_future = df_DOIs.merge(df_future_self, left_on='FinalDOI', right_on='DOI', how ='left')
df_future['FinalDOI'].mask(df_future.Recurated_DOI.notna(), df_future.Recurated_DOI, inplace=True)
df_future[df_future.Recurated_DOI.notna()]
df_future
# Out:
#         ID                         DOI_x  \
# 0     1125     10.1186/s12881-014-0095-4
# 1     1996   10.1183/13993003.00321-2016
# 2      506                           NaN
# 3     1430         10.1093/annonc/mdu449
# 4      848                           NaN
# ...    ...                           ...
# 2373  1838     10.1007/s00109-015-1377-9
# 2374  1103          10.1093/brain/awu143
# 2375  1065  10.1212/NXI.0000000000000016
# 2376    69                           NaN
# 2377    43                           NaN
#
#                                                complete  \
# 0     &amp; , fenwick al, goos jac, rankin j, lord h...
# 1     , pattinson kt, turner mr. a wider pathologica...
# 2     adib-samii p,  rost n,  traylor m,  devan w,  ...
# 3     and i. tomlinson*, findlay jm, middleton mr, t...
# 4     dichgans m,  malik r,  kã•_nig ir,  rosand j, ...
# ...                                                 ...
# 2373  zois ce, harris al. glycogen metabolism has a ...
# 2374  zokaei n, mcneill a, proukakis c, beavan m, ja...
# 2375  zuliani l, ferlazzo e, andrigo c, casano a, ci...
# 2376  zuliani l, graus f, giometto b, bien c, vincen...
# 2377  zweifel m, smith n, ross p, peters j, rustin g...
#
#                                          csv_post_title  \
# 0     apparently synonymous substitutions in fgfr2 a...
# 1     a wider pathological network underlying breath...
# 2     17q25 locus is associated with white matter hy...
# 3     a systematic review and meta-analysis of somat...
# 4     shared genetic susceptibility to ischemic stro...
# ...                                                 ...
# 2373  glycogen metabolism has a key role in the canc...
# 2374  visual short-term memory deficits associated w...
# 2375  glycine receptor antibodies in 2 cases of new,...
# 2376  central nervous system neuronal surface antibo...
# 2377  evaluation of cell death mechanisms induced by...
#
#                                        crossref_API_out  \
# 0     {'title': ['Apparently synonymous substitution...
# 1     {'title': ['A wider pathological network under...
# 2     {'title': ['17q25 Locus Is Associated With Whi...
# 3     {'title': ['A systematic review and meta-analy...
# 4     {'title': ['Shared Genetic Susceptibility to I...
# ...                                                 ...
# 2373  {'title': ['Glycogen metabolism has a key role...
# 2374  {'title': ['Visual short-term memory deficits ...
# 2375  {'title': ['Glycine receptor antibodies in 2 c...
# 2376  {'title': ['Central nervous system neuronal su...
# 2377  {'title': ['Evaluation of cell death mechanism...
#
#                                                   title  \
# 0     ['Apparently synonymous substitutions in FGFR2...
# 1     ['A wider pathological network underlying brea...
# 2     ['17q25 Locus Is Associated With White Matter ...
# 3     ['A systematic review and meta-analysis of som...
# 4     ['Shared Genetic Susceptibility to Ischemic St...
# ...                                                 ...
# 2373  ['Glycogen metabolism has a key role in the ca...
# 2374  ['Visual short-term memory deficits associated...
# 2375  ['Glycine receptor antibodies in 2 cases of ne...
# 2376  ['Central nervous system neuronal surface anti...
# 2377  ['Evaluation of cell death mechanisms induced ...
#
#                            DOI_API  \
# 0        10.1186/s12881-014-0095-4
# 1      10.1183/13993003.00321-2016
# 2     10.1161/strokeaha.113.679936
# 3            10.1093/annonc/mdu449
# 4     10.1161/strokeaha.113.002707
# ...                            ...
# 2373     10.1007/s00109-015-1377-9
# 2374          10.1093/brain/awu143
# 2375  10.1212/nxi.0000000000000016
# 2376      10.1136/jnnp-2011-301237
# 2377          10.1038/bjc.2012.165
#
#                                               title_API  title_match  \
# 0     Apparently synonymous substitutions in FGFR2af...        False
# 1     A wider pathological network underlying breath...         True
# 2     17q25 Locus Is Associated With White Matter Hy...         True
# 3     A systematic review and meta-analysis of somat...         True
# 4     Shared Genetic Susceptibility to Ischemic Stro...        False
# ...                                                 ...          ...
# 2373  Glycogen metabolism has a key role in the canc...         True
# 2374  Visual short-term memory deficits associated w...        False
# 2375  Glycine receptor antibodies in 2 cases of new,...        False
# 2376  Central nervous system neuronal surface antibo...         True
# 2377  Evaluation of cell death mechanisms induced by...         True
#
#       DOI_match  ... Complete_partialRatio  TitleMatch01  good_list  \
# 0          True  ...                  99.0             0       True
# 1          True  ...                 100.0             1       True
# 2         False  ...                 100.0             1       True
# 3          True  ...                 100.0             1       True
# 4         False  ...                 100.0             0       True
# ...         ...  ...                   ...           ...        ...
# 2373       True  ...                 100.0             1       True
# 2374       True  ...                  98.0             0       True
# 2375       True  ...                 100.0             0       True
# 2376      False  ...                 100.0             1       True
# 2377      False  ...                 100.0             1       True
#
#       good_list2  DOI_retry_API  title_retry_API  curated_DOI  \
# 0           True            NaN              NaN          NaN
# 1           True            NaN              NaN          NaN
# 2           True            NaN              NaN          NaN
# 3           True            NaN              NaN          NaN
# 4          False            NaN              NaN          NaN
# ...          ...            ...              ...          ...
# 2373        True            NaN              NaN          NaN
# 2374        True            NaN              NaN          NaN
# 2375        True            NaN              NaN          NaN
# 2376        True            NaN              NaN          NaN
# 2377        True            NaN              NaN          NaN
#
#                           FinalDOI  DOI_y Recurated_DOI
# 0        10.1186/s12881-014-0095-4    NaN           NaN
# 1      10.1183/13993003.00321-2016    NaN           NaN
# 2     10.1161/strokeaha.113.679936    NaN           NaN
# 3            10.1093/annonc/mdu449    NaN           NaN
# 4     10.1161/strokeaha.113.002707    NaN           NaN
# ...                            ...    ...           ...
# 2373     10.1007/s00109-015-1377-9    NaN           NaN
# 2374          10.1093/brain/awu143    NaN           NaN
# 2375  10.1212/nxi.0000000000000016    NaN           NaN
# 2376      10.1136/jnnp-2011-301237    NaN           NaN
# 2377          10.1038/bjc.2012.165    NaN           NaN
#
# [2378 rows x 25 columns]

# %%
df_future.dropna(subset=['FinalDOI'])[df_future.duplicated(subset=['FinalDOI'], keep=False)]
# Out:
# C:\Users\labrown\Miniconda3\envs\biblio-edge\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         ID                          DOI_x  \
# 607   2063              10.1111/bjh.14177
# 608   1359      10.1186/s12885-015-1048-9
# 725   2022              10.1111/liv.13163
# 872   1785  10.1016/j.metabol.2016.01.001
# 1609  2287              10.1111/liv.13284
# 1726  1119           10.1128/CVI.00099-14
# 1727  1102                            NaN
#
#                                                complete  \
# 607   eyre ta, clifford r, bloor a, boyle l, roberts...
# 608   eyre ta, clifford r, corran r, boyle l, franci...
# 725   gathercole ll, hazlehurst jm, armstrong mj, cr...
# 872   hazlehurst jm, woods c, marjot t, cobbold jf, ...
# 1609  pavlides m, banerjee r, tunnicliffe em, kelly ...
# 1726  ramasamy mn, clutterbuck ea, haworth k, barel ...
# 1727  ramasamy mn, clutterbuck ea, haworth k, bowman...
#
#                                          csv_post_title  \
# 607   ncri phase ii study of chop in combination wit...
# 608   single arm ncri phase ii study of chop in comb...
# 725   advanced non-alcoholic fatty liver disease and...
# 872      non-alcoholic fatty liver disease and diabetes
# 1609  multi-parametric magnetic resonance imaging fo...
# 1726  the immunogenicity of quadrivalent meningococc...
# 1727  randomized clinical trial to evaluate the immu...
#
#                                        crossref_API_out  \
# 607   {'title': ['NCRI phase II study of CHOP in com...
# 608   {'title': ['NCRI phase II study of CHOP in com...
# 725   {'title': ['Non-alcoholic fatty liver disease'...
# 872   {'title': ['Non-alcoholic fatty liver disease'...
# 1609  {'title': ['Non-alcoholic fatty liver disease'...
# 1726  {'title': ['Immunogenicity of meningococcal po...
# 1727  {'title': ['Randomized Clinical Trial To Evalu...
#
#                                                   title  \
# 607   ['NCRI phase II study of CHOP in combination w...
# 608   ['NCRI phase II study of CHOP in combination w...
# 725               ['Non-alcoholic fatty liver disease']
# 872               ['Non-alcoholic fatty liver disease']
# 1609              ['Non-alcoholic fatty liver disease']
# 1726  ['Immunogenicity of meningococcal polysacchari...
# 1727  ['Randomized Clinical Trial To Evaluate the Im...
#
#                                DOI_API  \
# 607                  10.1111/bjh.14177
# 608                  10.1111/bjh.14177
# 725   10.1111/j.1753-0407.2012.00204.x
# 872   10.1111/j.1753-0407.2012.00204.x
# 1609  10.1111/j.1753-0407.2012.00204.x
# 1726                 10.1111/cei.13202
# 1727              10.1128/cvi.00099-14
#
#                                               title_API  title_match  \
# 607   NCRI phase II study of CHOP in combination wit...         True
# 608   NCRI phase II study of CHOP in combination wit...        False
# 725                   Non-alcoholic fatty liver disease        False
# 872                   Non-alcoholic fatty liver disease        False
# 1609                  Non-alcoholic fatty liver disease        False
# 1726  Immunogenicity of meningococcal polysaccharide...        False
# 1727  Randomized Clinical Trial To Evaluate the Immu...         True
#
#       DOI_match  ... Complete_partialRatio  TitleMatch01  good_list  \
# 607        True  ...                 100.0             1       True
# 608       False  ...                  88.0             0       True
# 725       False  ...                 100.0             0       True
# 872       False  ...                 100.0             0       True
# 1609      False  ...                 100.0             0       True
# 1726      False  ...                  64.0             0      False
# 1727      False  ...                 100.0             1       True
#
#       good_list2         DOI_retry_API  \
# 607         True                   NaN
# 608        False                   NaN
# 725        False                   NaN
# 872        False                   NaN
# 1609       False                   NaN
# 1726        True  10.1128/cvi.00099-14
# 1727        True                   NaN
#
#                                         title_retry_API  curated_DOI  \
# 607                                                 NaN          NaN
# 608                                                 NaN          NaN
# 725                                                 NaN          NaN
# 872                                                 NaN          NaN
# 1609                                                NaN          NaN
# 1726  Randomized Clinical Trial To Evaluate the Immu...          NaN
# 1727                                                NaN          NaN
#
#                               FinalDOI  DOI_y Recurated_DOI
# 607                  10.1111/bjh.14177    NaN           NaN
# 608                  10.1111/bjh.14177    NaN           NaN
# 725   10.1111/j.1753-0407.2012.00204.x    NaN           NaN
# 872   10.1111/j.1753-0407.2012.00204.x    NaN           NaN
# 1609  10.1111/j.1753-0407.2012.00204.x    NaN           NaN
# 1726              10.1128/cvi.00099-14    NaN           NaN
# 1727              10.1128/cvi.00099-14    NaN           NaN
#
# [7 rows x 25 columns]

# %%
#  And following checking of final references, 6 duplicated FinalDOIs returned to 'DOIs'
df_future['FinalDOI'].mask((df_future.duplicated(subset=['FinalDOI'], keep=False)),
                         df_future.DOI_x, inplace=True)

# %%
#drop duplicate rows if needed  
#df_future.loc[1726:1727]

# references ID 1726 and 1727 are duplicates after manual curation
df_future.drop([1727], inplace=True)

# %%
# references ID 1326 is the preliminary version of 1812 are duplicates after manual curation (resolve to 10.1056/nejmoa1411627)

#df_future.query('ID==1326')  # gives index 1730
df_future.drop([1730], inplace=True)

# %%
df_future.query('ID==1326') #gone
# Out:
# Empty DataFrame
# Columns: [ID, DOI_x, complete, csv_post_title, crossref_API_out, title, DOI_API, title_API, title_match, DOI_match, CrossRefTitle_low, DOI_fuzzyRatio, Title_fuzzyRatio, Title_partialRatio, Complete_fuzzyRatio, Complete_partialRatio, TitleMatch01, good_list, good_list2, DOI_retry_API, title_retry_API, curated_DOI, FinalDOI, DOI_y, Recurated_DOI]
# Index: []
#
# [0 rows x 25 columns]

# %%
df_future.dropna(subset=['FinalDOI'])[df_future.duplicated(subset=['FinalDOI'], keep=False)]
# Out:
# C:\Users\labrown\Miniconda3\envs\biblio-edge\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [ID, DOI_x, complete, csv_post_title, crossref_API_out, title, DOI_API, title_API, title_match, DOI_match, CrossRefTitle_low, DOI_fuzzyRatio, Title_fuzzyRatio, Title_partialRatio, Complete_fuzzyRatio, Complete_partialRatio, TitleMatch01, good_list, good_list2, DOI_retry_API, title_retry_API, curated_DOI, FinalDOI, DOI_y, Recurated_DOI]
# Index: []
#
# [0 rows x 25 columns]

# %%
#unable to find good DOIs

df_future[df_future.FinalDOI.isnull()]
# Out:
#         ID DOI_x                                           complete  \
# 396    966   NaN  coffey s, prendergast b. medical therapies for...
# 809   1252   NaN  gutowska-owsiak d, salimi m, selvakumar ta, wa...
# 978   1408   NaN  isbarn h, briganti b, de visschere pj, fã•_tte...
# 1059   234   NaN  kavvoura fk, owen kr. maturity onset diabetes ...
# 1133   861   NaN  lang s, ford kj, john t, pollard aj, mccarthy ...
# 1682  1033   NaN  pollard aj. meningococcal disease prevention i...
# 1697    34   NaN  prendergast b, coope lt, crijns h, falkenstein...
# 1733  1056   NaN  rand l, sheehan m. healthcare resource allocat...
# 1751  1006   NaN  richens jl, vere ka, light ra, soria d, gariba...
# 1890  1611   NaN  sen a, selway r and nashe l. from channels to ...
# 1966  1612   NaN  sommerville er, michell aw, gabapenti sen a. t...
#
#                                          csv_post_title  \
# 396   medical therapies for treatment of valvular he...
# 809   histamine exerts multiple effects on expressio...
# 978   systematic ultrasound-guided saturation and te...
# 1059  maturity onset diabetes of the young: clinical...
# 1133  immunisation errors reported to a vaccine advi...
# 1682          meningococcal disease prevention in india
# 1697      the german centre for cardiovascular research
# 1733  healthcare resource allocation: balancing prin...
# 1751  practical detection of a definitive biomarker ...
# 1890  from channels to commissioning  -  a practical...
# 1966                          the treatment of epilepsy
#
#                                        crossref_API_out  \
# 396   {'title': ['Proceedings: Moving Toward Cell-Ba...
# 809   {'title': ['Topical hesperidin improves epider...
# 978   {'title': ['Transperineal template-guided mapp...
# 1059  {'title': ['Characteristics of maturity onset ...
# 1133  {'title': ['Energy advice service as perceived...
# 1682  {'title': ['Neonatal meningococcal disease'], ...
# 1697  {'title': ['Twenty years of research in the Hu...
# 1733                                               None
# 1751                                               None
# 1890  {'title': ['Practical guide to dynamic pelvic ...
# 1966  {'title': ['Novel approaches to epilepsy treat...
#
#                                                   title  \
# 396   ['Proceedings: Moving Toward Cell-Based Therap...
# 809   ['Topical hesperidin improves epidermal permea...
# 978   ['Transperineal template-guided mapping biopsy...
# 1059  ['Characteristics of maturity onset diabetes o...
# 1133  ['Energy advice service as perceived by Swedis...
# 1682                 ['Neonatal meningococcal disease']
# 1697  ['Twenty years of research in the Human Nutrit...
# 1733                                               None
# 1751                                               None
# 1890    ['Practical guide to dynamic pelvic floor MRI']
# 1966         ['Novel approaches to epilepsy treatment']
#
#                                DOI_API  \
# 396             10.5966/sctm.2015-0118
# 809   10.1111/j.1600-0625.2012.01455.x
# 978                  10.1111/iju.12660
# 1059                10.1111/pedi.12289
# 1133  10.1111/j.1470-6431.2010.00924.x
# 1682                 10.1111/jpc.13856
# 1697                 10.1111/nbu.12102
# 1733                              None
# 1751                              None
# 1890                10.1002/jmri.25998
# 1966                 10.1111/epi.12000
#
#                                               title_API  title_match  \
# 396   Proceedings: Moving Toward Cell-Based Therapie...        False
# 809   Topical hesperidin improves epidermal permeabi...        False
# 978   Transperineal template-guided mapping biopsy o...        False
# 1059  Characteristics of maturity onset diabetes of ...        False
# 1133  Energy advice service as perceived by Swedish ...        False
# 1682                     Neonatal meningococcal disease        False
# 1697  Twenty years of research in the Human Nutritio...        False
# 1733                                                NaN        False
# 1751                                                NaN        False
# 1890        Practical guide to dynamic pelvic floor MRI        False
# 1966             Novel approaches to epilepsy treatment        False
#
#       DOI_match  ... Complete_partialRatio  TitleMatch01  good_list  \
# 396       False  ...                  54.0             0      False
# 809       False  ...                  42.0             0      False
# 978       False  ...                  65.0             0      False
# 1059      False  ...                  65.0             0      False
# 1133      False  ...                  50.0             0      False
# 1682      False  ...                  80.0             0      False
# 1697      False  ...                  43.0             0      False
# 1733      False  ...                   NaN             0      False
# 1751      False  ...                   NaN             0      False
# 1890      False  ...                  58.0             0      False
# 1966      False  ...                  50.0             0      False
#
#       good_list2                     DOI_retry_API  \
# 396        False      10.1136/heartjnl-2016-310482
# 809        False  10.1111/j.1600-0625.2011.01412.x
# 978        False     10.1016/j.urolonc.2014.08.007
# 1059       False                 10.2217/dmt.12.82
# 1133       False             10.1093/pubmed/fdv112
# 1682       False              10.4161/hv.7.8.16270
# 1697       False      10.1016/j.bbamcr.2015.11.010
# 1733       False          10.1177/1471301215615780
# 1751       False                               NaN
# 1890       False       10.1016/j.yebeh.2018.03.016
# 1966       False                10.14581/jer.17012
#
#                                         title_retry_API  curated_DOI  \
# 396          Serum biomarkers in valvular heart disease          NaN
# 809   IL-17 downregulates filaggrin and affects kera...          NaN
# 978   Prognostic effect of neuroendocrine differenti...          NaN
# 1059  Biomarkers currently used for the diagnosis of...          NaN
# 1133  A quantitative review of healthcare profession...          NaN
# 1682  Meningococcal disease: The advances and challe...          NaN
# 1697                                 Heart regeneration          NaN
# 1733  Charles Foster, Jonathan Herring and Israel Do...          NaN
# 1751                                                NaN          NaN
# 1890  Bitemporal seizure spread and its effect on au...          NaN
# 1966  Cannabinoids in the Treatment of Epilepsy: Har...          NaN
#
#       FinalDOI  DOI_y Recurated_DOI
# 396        NaN    NaN           NaN
# 809        NaN    NaN           NaN
# 978        NaN    NaN           NaN
# 1059       NaN    NaN           NaN
# 1133       NaN    NaN           NaN
# 1682       NaN    NaN           NaN
# 1697       NaN    NaN           NaN
# 1733       NaN    NaN           NaN
# 1751       NaN    NaN           NaN
# 1890       NaN    NaN           NaN
# 1966       NaN    NaN           NaN
#
# [11 rows x 25 columns]

# %%
df_future.count()
# Out:
# ID                       2376
# DOI_x                    1442
# complete                 2376
# csv_post_title           2376
# crossref_API_out         2376
# title                    2376
# DOI_API                  2376
# title_API                2081
# title_match              2376
# DOI_match                2376
# CrossRefTitle_low        2081
# DOI_fuzzyRatio           1442
# Title_fuzzyRatio         2081
# Title_partialRatio       2081
# Complete_fuzzyRatio      2081
# Complete_partialRatio    2081
# TitleMatch01             2376
# good_list                2376
# good_list2               2376
# DOI_retry_API             561
# title_retry_API           561
# curated_DOI               164
# FinalDOI                 2365
# DOI_y                      14
# Recurated_DOI              14
# dtype: int64

# %%
df_future.columns
# Out:
# Index(['ID', 'DOI_x', 'complete', 'csv_post_title', 'crossref_API_out',
#        'title', 'DOI_API', 'title_API', 'title_match', 'DOI_match',
#        'CrossRefTitle_low', 'DOI_fuzzyRatio', 'Title_fuzzyRatio',
#        'Title_partialRatio', 'Complete_fuzzyRatio', 'Complete_partialRatio',
#        'TitleMatch01', 'good_list', 'good_list2', 'DOI_retry_API',
#        'title_retry_API', 'curated_DOI', 'FinalDOI', 'DOI_y', 'Recurated_DOI'],
#       dtype='object')

# %%
df_future.dropna(subset=['FinalDOI'])[df_future['FinalDOI'].duplicated(keep=False)]
# Out:
# C:\Users\labrown\Miniconda3\envs\biblio-edge\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [ID, DOI_x, complete, csv_post_title, crossref_API_out, title, DOI_API, title_API, title_match, DOI_match, CrossRefTitle_low, DOI_fuzzyRatio, Title_fuzzyRatio, Title_partialRatio, Complete_fuzzyRatio, Complete_partialRatio, TitleMatch01, good_list, good_list2, DOI_retry_API, title_retry_API, curated_DOI, FinalDOI, DOI_y, Recurated_DOI]
# Index: []
#
# [0 rows x 25 columns]

# %%
DOIs_out = df_future.reindex(columns=['ID','complete','FinalDOI']).dropna()

DOIs_out.sort_values('ID')
# Out:
#         ID                                           complete  \
# 342      1  chappell ma, woolrich mw, kazan s, jezzard p, ...
# 1893     2  serres s, soto ms, hamilton a, mcateer ma, car...
# 1206     3  lindsay ac, biasiolli l, lee, jm, kylintireas ...
# 1105     4  kolsch h, lehmann dj, ibrahim-verbaas ca, comb...
# 1317     5  markwick, a., zamboni, g., & de jager, c. a. (...
# ...    ...                                                ...
# 634   2416  faull ok, pattinson kt. the cortical connectiv...
# 877   2417  hellner k, dorrell l. recent advances in under...
# 976   2419  iro ma, snape md, voysey m, jawad s, finn a, h...
# 541   2420  duane f, aznar mc, bartlett f, cutter dj, darb...
# 1553  2421  ovseiko pv, chapple a, edmunds ld, ziebland s....
#
#                            FinalDOI
# 342               10.1002/mrm.24260
# 1893        10.1073/pnas.1117412109
# 1206     10.1016/j.jcmg.2011.10.007
# 1105      10.1007/s00702-011-0732-4
# 1317   10.1080/13803395.2012.672966
# ...                             ...
# 634             10.7554/elife.21749
# 877   10.12688/f1000research.9701.1
# 976   10.1016/j.vaccine.2016.11.009
# 541    10.1016/j.radonc.2017.01.008
# 1553      10.1186/s12961-017-0177-9
#
# [2365 rows x 3 columns]

# %%
DOIs_out.count()
# Out:
# ID          2365
# complete    2365
# FinalDOI    2365
# dtype: int64

# %%
DOIs_out.to_csv('./A5out.csv')

# %%
df_future.count().max()
# Out:
# 2376

# %%
print('Digital Object Identifiers (DOIs) found for % of refernces in Spreadsheet:')
print (((DOIs_out.FinalDOI.count()/df_DOIs.count().max())*100).round(2), '%')
# Out:
# Digital Object Identifiers (DOIs) found for % of refernces in Spreadsheet:
# 99.45 %
