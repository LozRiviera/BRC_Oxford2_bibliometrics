# %% [markdown]
# ### We will now bring together the lists of CrossRef-acquired DOIs and the manually-identified last few

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##  bring in the main list of all 2378 publications claimed in BRC phase2
#  file as exported from notebook A4   ('./CrossRef_BRC_FuzzyMatched_30Jun19.csv')

# %%
df_main = pd.read_csv('./A4out_CrossRef_FuzzyMatched_with_retry_07Aug19.csv', index_col=0)
df_main.shape
# Out:
# (2378, 20)

# %%
df_main.head(2)
# Out:
#                            DOI    ID  \
# 0    10.1186/s12881-014-0095-4  1125
# 1  10.1183/13993003.00321-2016  1996
#
#                                             complete  \
# 0  &amp; , fenwick al, goos jac, rankin j, lord h...
# 1  , pattinson kt, turner mr. a wider pathologica...
#
#                                     crossref_API_out  \
# 0  {'title': ['Apparently synonymous substitution...
# 1  {'title': ['A wider pathological network under...
#
#                                       csv_post_title  \
# 0  apparently synonymous substitutions in fgfr2 a...
# 1  a wider pathological network underlying breath...
#
#                        DOI_API  \
# 0    10.1186/s12881-014-0095-4
# 1  10.1183/13993003.00321-2016
#
#                                                title  \
# 0  ['Apparently synonymous substitutions in FGFR2...
# 1  ['A wider pathological network underlying brea...
#
#                                            title_API  title_match  DOI_match  \
# 0  Apparently synonymous substitutions in FGFR2af...        False       True
# 1  A wider pathological network underlying breath...         True       True
#
#                                    CrossRefTitle_low  DOI_fuzzyRatio  \
# 0  apparently synonymous substitutions in fgfr2af...           100.0
# 1  a wider pathological network underlying breath...           100.0
#
#    TitleMatch01  Title_fuzzyRatio  Title_partialRatio  Complete_fuzzyRatio  \
# 0             0              99.0                99.0                 51.0
# 1             1             100.0               100.0                 73.0
#
#    Complete_partialRatio  good_list DOI_retry_API title_retry_API
# 0                   99.0       True           NaN             NaN
# 1                  100.0       True           NaN             NaN

# %% [markdown]
# ## Then bring in the shorter list of Curated (manually checked) DOIs

# %%
df_curated = pd.read_csv('./A5in_Curated_DOIs(08Aug).csv', index_col=0, usecols=[0,1,4])
df_curated.head()
# Out:
#       ID                            DOI_curated
# 5   1312                     10.3174/ajnr.a4208
# 7     62  10.1016/j.atherosclerosis.2012.03.036
# 10   168                   10.1002/ajmg.a.35558
# 20  1920       10.1016/j.fertnstert.2014.12.123
# 21  1023       10.1136/archdischild-2013-304601

# %%
df_curated.count()
# Out:
# ID             385
# DOI_curated    374
# dtype: int64

# %%
#  extract the doi from the web URL
df_curated['curatedDOI'] = df_curated.DOI_curated.str.extract(r'(10\.\d{4,9}\/.[^ ]+)')

# %%
df_curated['curatedDOI'].count()
# Out:
# 374

# %%
df_curated.head()
# Out:
#       ID                            DOI_curated  \
# 5   1312                     10.3174/ajnr.a4208
# 7     62  10.1016/j.atherosclerosis.2012.03.036
# 10   168                   10.1002/ajmg.a.35558
# 20  1920       10.1016/j.fertnstert.2014.12.123
# 21  1023       10.1136/archdischild-2013-304601
#
#                                curatedDOI
# 5                      10.3174/ajnr.a4208
# 7   10.1016/j.atherosclerosis.2012.03.036
# 10                   10.1002/ajmg.a.35558
# 20       10.1016/j.fertnstert.2014.12.123
# 21       10.1136/archdischild-2013-304601

# %% [markdown]
# ### Then add 'curatedDOI column to df_api (merge using the 'ID' column)

# %%
df_DOIs = df_main.merge(df_curated, on='ID',how='left')
df_DOIs.shape
# Out:
# (2378, 22)

# %%
df_DOIs.count()
# Out:
# DOI                      1440
# ID                       2378
# complete                 2378
# crossref_API_out         2378
# csv_post_title           2378
# DOI_API                  2378
# title                    2378
# title_API                2352
# title_match              2378
# DOI_match                2378
# CrossRefTitle_low        2352
# DOI_fuzzyRatio           1440
# TitleMatch01             2378
# Title_fuzzyRatio         2352
# Title_partialRatio       2352
# Complete_fuzzyRatio      2352
# Complete_partialRatio    2352
# good_list                2378
# DOI_retry_API             379
# title_retry_API           379
# DOI_curated               374
# curatedDOI                374
# dtype: int64

# %% [markdown]
# ### Now define DOI to use from all references:
#     - If a curated DOI is available, use this

# %%
df_DOIs['FinalDOI']= np.nan

# %%
# be careful, the 'where' command is the reverse of this (replace when False)

df_DOIs['FinalDOI'].mask(df_DOIs.good_list==True, df_DOIs.DOI_API, inplace=True)

df_DOIs['FinalDOI'].mask(df_DOIs.curatedDOI.notna(), df_DOIs.curatedDOI, inplace=True)

df_DOIs['FinalDOI'] =df_DOIs['FinalDOI'].str.strip(' .')

# %%
df_DOIs.count()
# Out:
# DOI                      1440
# ID                       2378
# complete                 2378
# crossref_API_out         2378
# csv_post_title           2378
# DOI_API                  2378
# title                    2378
# title_API                2352
# title_match              2378
# DOI_match                2378
# CrossRefTitle_low        2352
# DOI_fuzzyRatio           1440
# TitleMatch01             2378
# Title_fuzzyRatio         2352
# Title_partialRatio       2352
# Complete_fuzzyRatio      2352
# Complete_partialRatio    2352
# good_list                2378
# DOI_retry_API             379
# title_retry_API           379
# DOI_curated               374
# curatedDOI                374
# FinalDOI                 2368
# dtype: int64

# %%
#unabel to find good DOIs

df_DOIs[df_DOIs.FinalDOI.isnull()]
# Out:
#       DOI    ID                                           complete  \
# 233   NaN   797  brittain js, brown p. the many roads to tremor...
# 396   NaN   966  coffey s, prendergast b. medical therapies for...
# 809   NaN  1252  gutowska-owsiak d, salimi m, selvakumar ta, wa...
# 978   NaN  1408  isbarn h, briganti b, de visschere pj, fã•_tte...
# 1133  NaN   861  lang s, ford kj, john t, pollard aj, mccarthy ...
# 1682  NaN  1033  pollard aj. meningococcal disease prevention i...
# 1697  NaN    34  prendergast b, coope lt, crijns h, falkenstein...
# 1751  NaN  1006  richens jl, vere ka, light ra, soria d, gariba...
# 1870  NaN   223  schmidt j, iversen akn, tenzer s, gostick e, p...
# 1890  NaN  1611  sen a, selway r and nashe l. from channels to ...
#
#                                        crossref_API_out  \
# 233   {'title': ['Simultaneous Thalamic and Posterio...
# 396   {'title': ['Proceedings: Moving Toward Cell-Ba...
# 809   {'title': ['Nrf2 links epidermal barrier funct...
# 978   {'title': ['Transperineal template-guided mapp...
# 1133  {'title': ['Energy advice service as perceived...
# 1682  {'title': ['Neonatal meningococcal disease'], ...
# 1697  {'title': ['Twenty years of research in the Hu...
# 1751  {'title': ['The Relationship Between Brain Agi...
# 1870  {'title': ['Polyubiquitination of lysine-48 is...
# 1890  {'title': ['Practical guide to dynamic pelvic ...
#
#                                          csv_post_title  \
# 233   the many roads to tremor: an invited commentar...
# 396   medical therapies for treatment of valvular he...
# 809   histamine exerts multiple effects on expressio...
# 978   systematic ultrasound-guided saturation and te...
# 1133  immunisation errors reported to a vaccine advi...
# 1682          meningococcal disease prevention in india
# 1697      the german centre for cardiovascular research
# 1751  practical detection of a definitive biomarker ...
# 1870                           rapid antigen processing
# 1890  from channels to commissioning  -  a practical...
#
#                                DOI_API  \
# 233   10.1111/j.1525-1403.2012.00503.x
# 396             10.5966/sctm.2015-0118
# 809             10.1002/emmm.201200219
# 978                  10.1111/iju.12660
# 1133  10.1111/j.1470-6431.2010.00924.x
# 1682                 10.1111/jpc.13856
# 1697                 10.1111/nbu.12102
# 1751      10.3724/sp.j.1206.2012.00351
# 1870             10.1002/eji.201444830
# 1890                10.1002/jmri.25998
#
#                                                   title  \
# 233   ['Simultaneous Thalamic and Posterior Subthala...
# 396   ['Proceedings: Moving Toward Cell-Based Therap...
# 809   ['Nrf2 links epidermal barrier function with a...
# 978   ['Transperineal template-guided mapping biopsy...
# 1133  ['Energy advice service as perceived by Swedis...
# 1682                 ['Neonatal meningococcal disease']
# 1697  ['Twenty years of research in the Human Nutrit...
# 1751  ['The Relationship Between Brain Aging and Pre...
# 1870  ['Polyubiquitination of lysine-48 is an essent...
# 1890    ['Practical guide to dynamic pelvic floor MRI']
#
#                                               title_API  title_match  \
# 233   Simultaneous Thalamic and Posterior Subthalami...        False
# 396   Proceedings: Moving Toward Cell-Based Therapie...        False
# 809   Nrf2 links epidermal barrier function with ant...        False
# 978   Transperineal template-guided mapping biopsy o...        False
# 1133  Energy advice service as perceived by Swedish ...        False
# 1682                     Neonatal meningococcal disease        False
# 1697  Twenty years of research in the Human Nutritio...        False
# 1751  The Relationship Between Brain Aging and Precl...        False
# 1870  Polyubiquitination of lysine-48 is an essentia...        False
# 1890        Practical guide to dynamic pelvic floor MRI        False
#
#       DOI_match  ... Title_fuzzyRatio  Title_partialRatio  \
# 233       False  ...             53.0                56.0
# 396       False  ...             54.0                56.0
# 809       False  ...             42.0                52.0
# 978       False  ...             45.0                65.0
# 1133      False  ...             40.0                51.0
# 1682      False  ...             59.0                70.0
# 1697      False  ...             34.0                49.0
# 1751      False  ...             38.0                54.0
# 1870      False  ...             35.0                88.0
# 1890      False  ...             41.0                51.0
#
#       Complete_fuzzyRatio  Complete_partialRatio  good_list  \
# 233                  47.0                   56.0      False
# 396                  48.0                   54.0      False
# 809                  31.0                   58.0      False
# 978                  28.0                   65.0      False
# 1133                 28.0                   50.0      False
# 1682                 48.0                   80.0      False
# 1697                 28.0                   43.0      False
# 1751                 31.0                   54.0      False
# 1870                 41.0                   46.0      False
# 1890                 31.0                   58.0      False
#
#                          DOI_retry_API  \
# 233    10.1016/j.expneurol.2013.06.009
# 396       10.1136/heartjnl-2016-310482
# 809   10.1111/j.1600-0625.2011.01412.x
# 978      10.1016/j.urolonc.2014.08.007
# 1133             10.1093/pubmed/fdv112
# 1682              10.4161/hv.7.8.16270
# 1697      10.1016/j.bbamcr.2015.11.010
# 1751           10.3233/jad-2011-111505
# 1870     10.1016/s0168-8278(12)60059-2
# 1890       10.1016/j.yebeh.2018.03.016
#
#                                         title_retry_API  DOI_curated  \
# 233   Effects of low-frequency thalamic deep brain s...          NaN
# 396          Serum biomarkers in valvular heart disease          NaN
# 809   IL-17 downregulates filaggrin and affects kera...          NaN
# 978   Prognostic effect of neuroendocrine differenti...          NaN
# 1133  A quantitative review of healthcare profession...          NaN
# 1682  Meningococcal disease: The advances and challe...          NaN
# 1697                                 Heart regeneration          NaN
# 1751  Identification of SPARC-like 1 Protein as Part...          NaN
# 1870  45 RAPID AND EFFICIENT ANTIGEN PROCESSING AND ...          NaN
# 1890  Bitemporal seizure spread and its effect on au...          NaN
#
#      curatedDOI FinalDOI
# 233         NaN      NaN
# 396         NaN      NaN
# 809         NaN      NaN
# 978         NaN      NaN
# 1133        NaN      NaN
# 1682        NaN      NaN
# 1697        NaN      NaN
# 1751        NaN      NaN
# 1870        NaN      NaN
# 1890        NaN      NaN
#
# [10 rows x 23 columns]

# %%
df_DOIs.count().max()
# Out:
# 2378

# %%
df_DOIs.dropna(subset=['FinalDOI'])[df_DOIs['FinalDOI'].duplicated(keep=False)]#.to_clipboard()
# Out:
# C:\Users\labrown\Miniconda3\envs\biblio_tools\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                        DOI    ID  \
# 1726  10.1128/CVI.00099-14  1119
# 1727                   NaN  1102
#
#                                                complete  \
# 1726  ramasamy mn, clutterbuck ea, haworth k, barel ...
# 1727  ramasamy mn, clutterbuck ea, haworth k, bowman...
#
#                                        crossref_API_out  \
# 1726  {'title': ['Immunogenicity of meningococcal po...
# 1727  {'title': ['Randomized Clinical Trial To Evalu...
#
#                                          csv_post_title               DOI_API  \
# 1726  the immunogenicity of quadrivalent meningococc...     10.1111/cei.13202
# 1727  randomized clinical trial to evaluate the immu...  10.1128/cvi.00099-14
#
#                                                   title  \
# 1726  ['Immunogenicity of meningococcal polysacchari...
# 1727  ['Randomized Clinical Trial To Evaluate the Im...
#
#                                               title_API  title_match  \
# 1726  Immunogenicity of meningococcal polysaccharide...        False
# 1727  Randomized Clinical Trial To Evaluate the Immu...         True
#
#       DOI_match  ... Title_fuzzyRatio  Title_partialRatio  \
# 1726      False  ...             65.0                64.0
# 1727      False  ...            100.0               100.0
#
#       Complete_fuzzyRatio  Complete_partialRatio  good_list  \
# 1726                 40.0                   64.0      False
# 1727                 76.0                  100.0       True
#
#              DOI_retry_API                                    title_retry_API  \
# 1726  10.1128/cvi.00099-14  Randomized Clinical Trial To Evaluate the Immu...
# 1727                   NaN                                                NaN
#
#                DOI_curated            curatedDOI              FinalDOI
# 1726  10.1128/cvi.00099-14  10.1128/cvi.00099-14  10.1128/cvi.00099-14
# 1727                   NaN                   NaN  10.1128/cvi.00099-14
#
# [2 rows x 23 columns]

# %%
#drop duplicate row
df_DOIs.drop([1727],inplace=True)

# %%
df_DOIs.columns
# Out:
# Index(['DOI', 'ID', 'complete', 'crossref_API_out', 'csv_post_title',
#        'DOI_API', 'title', 'title_API', 'title_match', 'DOI_match',
#        'CrossRefTitle_low', 'DOI_fuzzyRatio', 'TitleMatch01',
#        'Title_fuzzyRatio', 'Title_partialRatio', 'Complete_fuzzyRatio',
#        'Complete_partialRatio', 'good_list', 'DOI_retry_API',
#        'title_retry_API', 'DOI_curated', 'curatedDOI', 'FinalDOI'],
#       dtype='object')

# %%
DOIs_out = df_DOIs.reindex(columns=['ID','complete','FinalDOI']).dropna()
DOIs_out.to_csv('./A5out_2367_correctDOIs_for_metrics(08Aug19).csv')
DOIs_out.sort_values('ID')
# Out:
#         ID                                           complete  \
# 342      1  chappell ma, woolrich mw, kazan s, jezzard p, ...
# 1893     2  serres s, soto ms, hamilton a, mcateer ma, car...
# 1206     3  lindsay ac, biasiolli l, lee, jm, kylintireas ...
# 1105     4  kolsch h, lehmann dj, ibrahim-verbaas ca, comb...
# 1317     5  markwick, a., zamboni, g., & de jager, c. a. (...
# 2142     6  valent. identification and functional characte...
# 1861     7  schã•_del j,  bardella c,  sciesielski lk,  br...
# 1457     8  munnå½ s,  held kr,  magli cm,  ata b,  wells ...
# 1027     9  jubb am, browning l, campo l, turley h, steers...
# 1114    10  kramer-marek g, gijsen m, kiesewetter do, benn...
# 1287    11  majounie e,  renton ae,  mok k,  dopper eg,  w...
# 1654    12  phadwal k, alegre-abarrategui j, watson as, pi...
# 152     13  becker eb, zuliani l, pettingill r, lang b, wa...
# 418     14  crack lr, chan hw, mcpherson t, ogg g. identif...
# 1416    15  minassian am, satti i, poulton id, meyer j, hi...
# 1399    16  metz ja, hanieh s, pradhan r, joshi a, shakya ...
# 771     17  gough sc. liraglutide: from clinical trials to...
# 76      18  antoniades ca, ober j, hicks s, siuda g, carpe...
# 1025    19  joundi ra, brittain js, punt td, green al, jen...
# 692     20  fragouli e, wells d. aneuploidy screening for ...
# 906     21  hirst ja, taylor ks, stevens rj, blacklock cl,...
# 339     22  chapel h. classification of primary immunodefi...
# 1965    23  solomon t, michael bd, smith pe, sanderson f, ...
# 429     24  cross se, hughes sj, clark a, gray dw, johnson...
# 2254    25  westcar s, ford kj , kelly sc, snape md. antip...
# 761     26  goodyear oc, dennis m, jilani ny, loke j, sidd...
# 1875    27  schulz c, gomez perdiguero e, chorro l, szabo-...
# 2193    28  vrdoljak a, mcgrath mg, carey jb, draper sj, h...
# 188     29  biswas s, spencer aj, forbes ek, gilbert sc, h...
# 1075    30  khatami a, snape md, davis e, layton h, john t...
# ...    ...                                                ...
# 1324  2388  martin ge, gossez m, williams jp, stohr w, mey...
# 664   2389  fidler s, olson ad, bucher hc, fox j, thornhil...
# 1193  2390  liao c, ashley n, diot a, morten k, phadwal k,...
# 1053  2391  kasela s, kisand k, tserel l, kaleviste e, rem...
# 1497  2392  neville mj, lee w, humburg p, wong d, barnardo...
# 334   2394  chand m, lamagni t, kranzer k, hedge j, moore ...
# 1336  2395  mathers aj, stoesser n, chai w, carroll j, bar...
# 1541  2396  orlek a, stoesser n, anjum mf, doumith m, elli...
# 36    2397  ajileye a, alvarez n, merker m, walker tm, akt...
# 1684  2398  popitsch n, schuh a, taylor jc. reliablegenome...
# 78    2399  antonisamy b, vasan sk, geethanjali fs, gowri ...
# 308   2400  carrat gr, hu m, nguyen-tu ms, chabosseau p, g...
# 1023  2401  josse rg, majumdar sr, zheng y, adler a, bethe...
# 1318  2402  marouli e, graff m, medina-gomez c, lo ks, woo...
# 1852  2403  sandholm n, van zuydam n, ahlqvist e, juliusdo...
# 1906  2404  shaw d, georgieva d, haase b, gardiner d, lewi...
# 1538  2406  o'neill gc, tewarie pk, colclough gl, gascoyne...
# 1704  2407  proudfoot m, rohenkohl g, quinn a, colclough g...
# 2024  2408  suri s, emir u, stagg cj, near j, mekle r, sch...
# 1275  2410  maclaren re. electronic retinal implant surger...
# 1602  2411  patricio mi, barnard ar, orlans ho, mcclements...
# 1942  2412  simunovic mp, xue k, jolly jk, maclaren re. st...
# 1338  2413  matin tn, rahman n, nickol ah, chen m, xu x, s...
# 1537  2414  o'neil dp, robbins pa. a mechanistic physicoch...
# 2120  2415  turnbull cd, akoumianakis i, antoniades c, str...
# 634   2416  faull ok, pattinson kt. the cortical connectiv...
# 877   2417  hellner k, dorrell l. recent advances in under...
# 976   2419  iro ma, snape md, voysey m, jawad s, finn a, h...
# 541   2420  duane f, aznar mc, bartlett f, cutter dj, darb...
# 1553  2421  ovseiko pv, chapple a, edmunds ld, ziebland s....
#
#                                  FinalDOI
# 342                     10.1002/mrm.24260
# 1893              10.1073/pnas.1117412109
# 1206           10.1016/j.jcmg.2011.10.007
# 1105            10.1007/s00702-011-0732-4
# 1317         10.1080/13803395.2012.672966
# 2142         10.1371/journal.pone.0034541
# 1861                      10.1038/ng.2204
# 1457     10.1016/j.fertnstert.2012.01.106
# 1027     10.1111/j.1365-2559.2011.04138.x
# 1114            10.2967/jnumed.111.096685
# 1287           10.1016/j.yneu.2012.05.040
# 1654                   10.4161/auto.18935
# 152              10.1136/jnnp-2011-301506
# 418      10.1111/j.1365-2230.2011.04227.x
# 1416                10.1093/infdis/jis012
# 1399         10.1097/inf.0b013e31824a9c37
# 771      10.1111/j.1463-1326.2012.01576.x
# 76              10.1007/s11517-012-0863-2
# 1025         10.1097/wnr.0b013e3283525b39
# 692                10.1055/s-0032-1313908
# 906                   10.1038/ki.2011.413
# 339      10.1111/j.1365-2249.2012.04561.x
# 1965           10.1016/j.jinf.2011.11.014
# 429              10.3727/096368912x636975
# 2254          10.12968/pnur.2012.23.4.183
# 761          10.1182/blood-2011-09-377044
# 1875              10.1126/science.1219179
# 2193        10.1016/j.jconrel.2011.12.026
# 188              10.4049/jimmunol.1101106
# 1075  10.1136/archdischild-2012-301885.56
# ...                                   ...
# 1324         10.1097/qad.0000000000001382
# 664          10.1097/qai.0000000000001220
# 1193         10.1212/wnl.0000000000003491
# 1053         10.1371/journal.pgen.1006643
# 1497         10.1016/j.humimm.2017.01.006
# 334                    10.1093/cid/ciw754
# 1336                 10.1128/aac.01823-16
# 1541             10.3389/fmicb.2017.00182
# 36                   10.1128/aac.02169-16
# 1684        10.1093/bioinformatics/btw587
# 78            10.1016/j.jpeds.2016.09.059
# 308            10.1016/j.ajhg.2017.01.011
# 1023                    10.1111/dom.12786
# 1318                  10.1038/nature21039
# 1852               10.1681/asn.2016020231
# 1906          10.1097/tp.0000000000001536
# 1538     10.1016/j.neuroimage.2016.08.061
# 1704                    10.1002/hbm.23357
# 2024     10.1016/j.neuroimage.2017.03.031
# 1275                 10.1038/eye.2016.280
# 1602           10.1016/j.omtn.2016.12.006
# 1942     10.1001/jamaophthalmol.2016.5630
# 1338            10.1148/radiol.2016152299
# 1537      10.1152/japplphysiol.00318.2016
# 2120          10.1183/13993003.01787-2016
# 634                   10.7554/elife.21749
# 877         10.12688/f1000research.9701.1
# 976         10.1016/j.vaccine.2016.11.009
# 541          10.1016/j.radonc.2017.01.008
# 1553            10.1186/s12961-017-0177-9
#
# [2367 rows x 3 columns]

# %%
DOIs_out.count()
# Out:
# ID          2367
# complete    2367
# FinalDOI    2367
# dtype: int64

# %%
df_DOIs.count().max()
# Out:
# 2377

# %%
print('Digital Object Identifiers (DOIs) forund for % of refernces in Spreadsheet:')
print (((DOIs_out.FinalDOI.count()/df_DOIs.count().max())*100).round(2), '%')
# Out:
# Digital Object Identifiers (DOIs) forund for % of refernces in Spreadsheet:
# 99.58 %
