# %% [markdown]
# ## Comparing titles acquired from CrossRef API with original title used as search string
# ## and also checking manually-recorded DOIs in original spreadsheet with those returned by CrossRef.
#
# ### Reasoning:
# - where title matches orinigal record, the corresponding DOI is correct
# - where DOI matches and title matches, even more sure
# - Where DOI matches original in record (having searched using manually recorded title string, DOI correct
# - no match on either -- check further

# %% [markdown]
# ### only the Pandas python library needed this time

# %%
import pandas as pd

# %% [markdown]
# ### First bring in the existing list of publictaions (using the columns needed)

# %%
df_json = pd.read_json('./A1out_CrossRef_BRC_Bodlist_BODandCrossRefDois_05Aug19.json', orient='records', lines=True)

df_json.head()
# Out:
#                            DOI    ID  \
# 0    10.1186/s12881-014-0095-4  1125
# 1  10.1183/13993003.00321-2016  1996
# 2                         None   506
# 3        10.1093/annonc/mdu449  1430
# 4                         None   848
#
#                                             complete  \
# 0   &amp; , Fenwick AL, Goos JAC, Rankin J, Lord ...
# 1   , Pattinson KT, Turner MR. A wider pathologic...
# 2   Adib-Samii P,  Rost N,  Traylor M,  Devan W, ...
# 3   and I. Tomlinson*, Findlay JM, Middleton MR, ...
# 4   Dichgans M,  Malik R,  KÃ•_nig IR,  Rosand J,...
#
#                                     crossref_API_out  \
# 0  {'title': ['Apparently synonymous substitution...
# 1  {'title': ['A wider pathological network under...
# 2  {'title': ['17q25 Locus Is Associated With Whi...
# 3  {'title': ['A systematic review and meta-analy...
# 4  {'title': ['Shared Genetic Susceptibility to I...
#
#                                       csv_post_title
# 0  Apparently synonymous substitutions in FGFR2 a...
# 1  A wider pathological network underlying breath...
# 2  17q25 Locus is associated with white matter hy...
# 3  A systematic review and meta-analysis of somat...
# 4  Shared genetic susceptibility to ischemic stro...

# %%
newdata =pd.read_json(df_json.crossref_API_out.to_json()).transpose()
newdata
# Out:
#                                    DOI  \
# 0            10.1186/s12881-014-0095-4
# 1          10.1183/13993003.00321-2016
# 2         10.1161/strokeaha.113.679936
# 3                10.1093/annonc/mdu449
# 4         10.1161/strokeaha.113.002707
# 5     10.1111/j.1749-6632.2012.06732.x
# 6                    10.1111/bjd.13199
# 7                   10.1002/lary.23844
# 8            10.1007/s10608-016-9795-8
# 9                      10.1038/ng.2492
# 10                  10.1002/lary.25544
# 11              10.3201/eid2204.151812
# 12                 10.7554/elife.03821
# 13                  10.1111/dote.12244
# 14           10.1016/j.dib.2016.08.046
# 15                10.1128/jcm.00330-16
# 16                  10.3233/jad-150862
# 17                   10.1002/art.38873
# 18    10.1016/j.neuroimage.2014.03.056
# 19                   10.1111/bjh.13380
# 20                     10.1002/pd.4665
# 21    10.1111/j.1365-2893.2011.01456.x
# 22        10.1097/nen.0000000000000173
# 23        10.1016/j.celrep.2013.04.006
# 24            10.1186/1745-6215-14-161
# 25        10.1161/strokeaha.114.006849
# 26                    10.1002/rmv.1907
# 27        10.1371/journal.ppat.1004954
# 28                  10.1038/mt.2016.83
# 29          10.1016/j.jaci.2014.04.031
# ...                                ...
# 2348                 10.1111/bdi.12047
# 2349      10.1016/j.schres.2014.11.001
# 2350    10.1001/2013.jamapsychiatry.86
# 2351    10.1523/jneurosci.1036-13.2013
# 2352             10.1093/cercor/bhv244
# 2353  10.1016/j.neuroimage.2016.05.031
# 2354                 10.1002/mds.25517
# 2355    10.1523/jneurosci.1169-14.2014
# 2356        10.1016/j.brat.2015.05.016
# 2357        10.1016/j.cell.2013.09.017
# 2358               10.1093/jnci/djv219
# 2359        10.1016/j.cmet.2013.10.014
# 2360      10.1371/journal.pone.0131833
# 2361        10.1016/j.jcyt.2015.05.015
# 2362           10.1136/bcr-2015-213573
# 2363     10.1158/1078-0432.ccr-12-3647
# 2364                10.1111/jocs.12295
# 2365              10.1056/nejmc1608082
# 2366     10.1016/s2213-8587(14)70050-6
# 2367                   10.1038/ng.3632
# 2368      10.1371/journal.pone.0150576
# 2369          10.1186/1471-2334-12-164
# 2370     10.1158/1078-0432.ccr-16-1562
# 2371     10.1158/1078-0432.ccr-14-0341
# 2372  10.1111/j.1742-4658.2012.08644.x
# 2373         10.1007/s00109-015-1377-9
# 2374              10.1093/brain/awu143
# 2375      10.1212/nxi.0000000000000016
# 2376          10.1136/jnnp-2011-301237
# 2377              10.1038/bjc.2012.165
#
#                                                   title
# 0     [Apparently synonymous substitutions in FGFR2a...
# 1     [A wider pathological network underlying breat...
# 2     [17q25 Locus Is Associated With White Matter H...
# 3     [A systematic review and meta-analysis of soma...
# 4     [Shared Genetic Susceptibility to Ischemic Str...
# 5     [Imaging-based selection in acute ischemic str...
# 6     [The histamine-synthesizing enzyme histidine d...
# 7                 [Obstructive sleep apnea in children]
# 8     [Mental Imagery-Based Training to Modify Mood ...
# 9     [Mutations in AP2S1 cause familial hypocalciur...
# 10    [High-frequency sensorineural hearing loss in ...
# 11    [Evaluation of Viremia Frequencies of a Novel ...
# 12    [HIV-1 DNA predicts disease progression and po...
# 13    [Attempted validation of the NUn score and inf...
# 14    [Data showing non-conventional HLA-B27 express...
# 15    [Comparison of Next-Generation Sequencing Tech...
# 16    [A Validation Study of Vascular Cognitive Impa...
# 17    [Genetic Dissection of Acute Anterior Uveitis ...
# 18    [Gray matter volume is associated with rate of...
# 19    [Ofatumumab retreatment and maintenance in flu...
# 20    [Validation of a semiconductor next-generation...
# 21    [Chronic hepatitis C in children - review of n...
# 22    [Reduction in Serum Aquaporin-4 Antibody Titer...
# 23    [A Role for Cytosolic Fumarate Hydratase in Ur...
# 24    [Effects of emotion recognition training on mo...
# 25    [Genetic Architecture of White Matter Hyperint...
# 26    [Review of cytomegalovirus coinfection in HIV-...
# 27    [Discordant Impact of HLA on Viral Replicative...
# 28    [Safety and Immunogenicity of ChAd63 and MVA M...
# 29    [Characterization of Crohn disease in X-linked...
# ...                                                 ...
# 2348  [Differences in resting corticolimbic function...
# 2349  [Immunotherapy for patients with acute psychos...
# 2350  [Increased Prevalence of Diverse N -Methyl-D-A...
# 2351  [Subthalamic Nucleus Local Field Potential Act...
# 2352  [Human Subthalamic Nucleus Theta and Beta Osci...
# 2353  [Human subthalamic nucleus–medial frontal cort...
# 2354  [Pathological crying after subthalamic nucleus...
# 2355  [Midline Frontal Cortex Low-Frequency Activity...
# 2356  [The effect of positive mood induction on redu...
# 2357  [A Polymorphic p53 Response Element in KIT Lig...
# 2358  [Height and Breast Cancer Risk: Evidence From ...
# 2359  [Role of KATP Channels in Glucose-Regulated Gl...
# 2360  [CDK5 Regulates Paclitaxel Sensitivity in Ovar...
# 2361  [An innovative method to generate a Good Manuf...
# 2362  [Acute EBV masquerading as peripheral T-cell l...
# 2363  [Functional Profiling of Receptor Tyrosine Kin...
# 2364  [Complete Atrioventricular Septal Defect: Comp...
# 2365    [Perioperative Rosuvastatin in Cardiac Surgery]
# 2366  [Heritability of variation in glycaemic respon...
# 2367  [Variation in the glucose transporter gene SLC...
# 2368  [Development and Evaluation of a Blood Culture...
# 2369  [A novel method of selective removal of human ...
# 2370  [A Novel Compound ARN-3236 Inhibits Salt-Induc...
# 2371  [Phase I Expansion and Pharmacodynamic Study o...
# 2372                       [Lipid metabolism in cancer]
# 2373  [Glycogen metabolism has a key role in the can...
# 2374  [Visual short-term memory deficits associated ...
# 2375  [Glycine receptor antibodies in 2 cases of new...
# 2376  [Central nervous system neuronal surface antib...
# 2377  [Evaluation of cell death mechanisms induced b...
#
# [2378 rows x 2 columns]

# %%
df_combo =df_json.join(newdata, rsuffix='_API')

# %%
df_combo['title_API'] =  df_combo.title.str[0]
df_combo['title_API'].where(df_combo.title_API.str.len()>=10, inplace=True)

# %%
df_combo.head()
# Out:
#                            DOI    ID  \
# 0    10.1186/s12881-014-0095-4  1125
# 1  10.1183/13993003.00321-2016  1996
# 2                         None   506
# 3        10.1093/annonc/mdu449  1430
# 4                         None   848
#
#                                             complete  \
# 0   &amp; , Fenwick AL, Goos JAC, Rankin J, Lord ...
# 1   , Pattinson KT, Turner MR. A wider pathologic...
# 2   Adib-Samii P,  Rost N,  Traylor M,  Devan W, ...
# 3   and I. Tomlinson*, Findlay JM, Middleton MR, ...
# 4   Dichgans M,  Malik R,  KÃ•_nig IR,  Rosand J,...
#
#                                     crossref_API_out  \
# 0  {'title': ['Apparently synonymous substitution...
# 1  {'title': ['A wider pathological network under...
# 2  {'title': ['17q25 Locus Is Associated With Whi...
# 3  {'title': ['A systematic review and meta-analy...
# 4  {'title': ['Shared Genetic Susceptibility to I...
#
#                                       csv_post_title  \
# 0  Apparently synonymous substitutions in FGFR2 a...
# 1  A wider pathological network underlying breath...
# 2  17q25 Locus is associated with white matter hy...
# 3  A systematic review and meta-analysis of somat...
# 4  Shared genetic susceptibility to ischemic stro...
#
#                         DOI_API  \
# 0     10.1186/s12881-014-0095-4
# 1   10.1183/13993003.00321-2016
# 2  10.1161/strokeaha.113.679936
# 3         10.1093/annonc/mdu449
# 4  10.1161/strokeaha.113.002707
#
#                                                title  \
# 0  [Apparently synonymous substitutions in FGFR2a...
# 1  [A wider pathological network underlying breat...
# 2  [17q25 Locus Is Associated With White Matter H...
# 3  [A systematic review and meta-analysis of soma...
# 4  [Shared Genetic Susceptibility to Ischemic Str...
#
#                                            title_API
# 0  Apparently synonymous substitutions in FGFR2af...
# 1  A wider pathological network underlying breath...
# 2  17q25 Locus Is Associated With White Matter Hy...
# 3  A systematic review and meta-analysis of somat...
# 4  Shared Genetic Susceptibility to Ischemic Stro...

# %%
df_matched = df_combo.assign(
    title_match = df_combo.csv_post_title.str.strip().str.lower()==df_combo.title_API.str.strip().str.lower(),
    DOI_match = df_combo.DOI.str.strip().str.lower()==df_combo.DOI_API.str.strip().str.lower() )

# %%
df_matched.groupby(['title_match']).count()
# Out:
#              DOI    ID  complete  crossref_API_out  csv_post_title  DOI_API  \
# title_match
# False        655  1032      1032              1032            1032     1032
# True         785  1346      1346              1346            1346     1346
#
#              title  title_API  DOI_match
# title_match
# False         1032       1006       1032
# True          1346       1346       1346

# %%
df_for_DOI_match =df_matched[df_matched.title_match==False]

df_for_DOI_match.groupby(['DOI_match']).count()
# Out:
#            DOI   ID  complete  crossref_API_out  csv_post_title  DOI_API  \
# DOI_match
# False      268  645       645               645             645      645
# True       387  387       387               387             387      387
#
#            title  title_API  title_match
# DOI_match
# False        645        619          645
# True         387        387          387

# %%
df_matched.to_csv('./A2out_CrossRef_BRC_matched_and_unmmatched_06Aug19.csv')
df_matched.to_json('./A2out_CrossRef_BRC_matched_and_unmmatched_06Aug19.json', orient='records', lines=True)

# %%
df_unmatched =df_for_DOI_match[df_for_DOI_match.DOI_match==False]
df_unmatched.shape
# Out:
# (645, 10)

# %%
df_unmatched.to_csv('./A2out_CrossRef_BRC_unmatched_06Aug19.csv')
